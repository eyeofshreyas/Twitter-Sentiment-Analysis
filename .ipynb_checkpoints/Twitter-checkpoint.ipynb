# %%
import numpy as np
import pandas as pd
import requests
import pickle
import re
import scipy.sparse
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

from nltk.stem.porter import PorterStemmer
from nltk.corpus import stopwords
from sklearn.metrics import accuracy_score
import nltk
nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt_tab', quiet=True)
# Out:
# True

# %%
print(stopwords.words("english"))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# DATA Processing

# %%
import csv
column_names = ['target', 'id', 'date', 'flag', 'user', 'text']
twitter_data = pd.read_csv(
    'twitter_data.csv',
    names=column_names,
    encoding='ISO-8859-1',
    quoting=csv.QUOTE_NONE,
    on_bad_lines='skip'
)

# %%
# checking the number of rows and columns
twitter_data.shape
# Out:
# (83067, 6)

# %%
#print 5 rows of dataset
twitter_data.head()
# Out:
#                                                                   target  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                      "NO_QUERY"
# "0"       "1998864136"                    "Mon Jun 01 19:15:00 PDT 2009"
#           "1998864367"                    "Mon Jun 01 19:15:01 PDT 2009"
#           "1998864497"                    "Mon Jun 01 19:15:02 PDT 2009"
#           "1998864564"                    "Mon Jun 01 19:15:02 PDT 2009"
#
#                                                      id  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "ana_cassini"
# "0"       "1998864136"                       "NO_QUERY"
#           "1998864367"                       "NO_QUERY"
#           "1998864497"                       "NO_QUERY"
#           "1998864564"                       "NO_QUERY"
#
#                                                                                        date  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "Unf...Mel didn't twit today!  Watchin' some T...
# "0"       "1998864136"                                                          "stratagee"
#           "1998864367"                                                         "hbturner75"
#           "1998864497"                                                          "sher_in_a"
#           "1998864564"                                                         "move_a1ong"
#
#                                                                                        flag  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                         taking a look at the forum
# "0"       "1998864136"                    "Vanished one day and I really hope he is oook...
#           "1998864367"                               "Wanting to be with my man but can't "
#           "1998864497"                                        "missing my sweet lily Ava! "
#           "1998864564"                                   "still sick  school tomorroww UGH"
#
#                                                                    user  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  listening to some music! Yeay
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN
#
#                                                                    text
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  I'm a multiple tasks person!"
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN

# %%
twitter_data.head()
# Out:
#                                                                   target  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                      "NO_QUERY"
# "0"       "1998864136"                    "Mon Jun 01 19:15:00 PDT 2009"
#           "1998864367"                    "Mon Jun 01 19:15:01 PDT 2009"
#           "1998864497"                    "Mon Jun 01 19:15:02 PDT 2009"
#           "1998864564"                    "Mon Jun 01 19:15:02 PDT 2009"
#
#                                                      id  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "ana_cassini"
# "0"       "1998864136"                       "NO_QUERY"
#           "1998864367"                       "NO_QUERY"
#           "1998864497"                       "NO_QUERY"
#           "1998864564"                       "NO_QUERY"
#
#                                                                                        date  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "Unf...Mel didn't twit today!  Watchin' some T...
# "0"       "1998864136"                                                          "stratagee"
#           "1998864367"                                                         "hbturner75"
#           "1998864497"                                                          "sher_in_a"
#           "1998864564"                                                         "move_a1ong"
#
#                                                                                        flag  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                         taking a look at the forum
# "0"       "1998864136"                    "Vanished one day and I really hope he is oook...
#           "1998864367"                               "Wanting to be with my man but can't "
#           "1998864497"                                        "missing my sweet lily Ava! "
#           "1998864564"                                   "still sick  school tomorroww UGH"
#
#                                                                    user  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  listening to some music! Yeay
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN
#
#                                                                    text
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  I'm a multiple tasks person!"
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN

# %%
twitter_data.head()
# Out:
#                                                                   target  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                      "NO_QUERY"
# "0"       "1998864136"                    "Mon Jun 01 19:15:00 PDT 2009"
#           "1998864367"                    "Mon Jun 01 19:15:01 PDT 2009"
#           "1998864497"                    "Mon Jun 01 19:15:02 PDT 2009"
#           "1998864564"                    "Mon Jun 01 19:15:02 PDT 2009"
#
#                                                      id  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "ana_cassini"
# "0"       "1998864136"                       "NO_QUERY"
#           "1998864367"                       "NO_QUERY"
#           "1998864497"                       "NO_QUERY"
#           "1998864564"                       "NO_QUERY"
#
#                                                                                        date  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "Unf...Mel didn't twit today!  Watchin' some T...
# "0"       "1998864136"                                                          "stratagee"
#           "1998864367"                                                         "hbturner75"
#           "1998864497"                                                          "sher_in_a"
#           "1998864564"                                                         "move_a1ong"
#
#                                                                                        flag  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                         taking a look at the forum
# "0"       "1998864136"                    "Vanished one day and I really hope he is oook...
#           "1998864367"                               "Wanting to be with my man but can't "
#           "1998864497"                                        "missing my sweet lily Ava! "
#           "1998864564"                                   "still sick  school tomorroww UGH"
#
#                                                                    user  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  listening to some music! Yeay
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN
#
#                                                                    text
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  I'm a multiple tasks person!"
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN

# %%
# counting the number of missing valuse in the dataset
twitter_data.isnull().sum()
# Out:
# target        0
# id            0
# date          0
# flag          0
# user      65718
# text      79831
# dtype: int64

# %%
# checking the distribution of target column
twitter_data['target'].value_counts()
# Out:
# target
# "Fri Jun 05 11:02:30 PDT 2009"    7
# "Fri Jun 05 23:58:20 PDT 2009"    6
# "Tue Jun 02 13:35:11 PDT 2009"    6
# "Thu Jun 04 09:08:32 PDT 2009"    6
# "Fri Jun 05 14:58:26 PDT 2009"    6
#                                  ..
# "Sat Jun 06 05:31:47 PDT 2009"    1
# "Sat Jun 06 05:31:52 PDT 2009"    1
# "Sat Jun 06 05:31:55 PDT 2009"    1
# "Sat Jun 06 05:31:59 PDT 2009"    1
# "Sat Jun 06 05:32:02 PDT 2009"    1
# Name: count, Length: 62080, dtype: int64

# %% [markdown]
# convert target 4 to 1

# %%
twitter_data.replace({'target': {4: 1}}, inplace=True)

# %%
# Checking the distribution of target column
twitter_data['target'].value_counts()
# Out:
# target
# "Fri Jun 05 11:02:30 PDT 2009"    7
# "Fri Jun 05 23:58:20 PDT 2009"    6
# "Tue Jun 02 13:35:11 PDT 2009"    6
# "Thu Jun 04 09:08:32 PDT 2009"    6
# "Fri Jun 05 14:58:26 PDT 2009"    6
#                                  ..
# "Sat Jun 06 05:31:47 PDT 2009"    1
# "Sat Jun 06 05:31:52 PDT 2009"    1
# "Sat Jun 06 05:31:55 PDT 2009"    1
# "Sat Jun 06 05:31:59 PDT 2009"    1
# "Sat Jun 06 05:32:02 PDT 2009"    1
# Name: count, Length: 62080, dtype: int64

# %% [markdown]
# **Stemming**
#
# Stemming is the process of reducing a word to ist Root word

# %%
post_stem=PorterStemmer()

# %%
def stemming(content):
  if isinstance(content, float):
    return '' # Return empty string for NaN or other float values
  stemmed_content=re.sub('[^a-zA-Z]',' ',content) # Corrected regex to remove non-alphabetic chars
  stemmed_content=stemmed_content.lower()
  stemmed_content=stemmed_content.split()
  stemmed_content=[post_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
  stemmed_content=' '.join(stemmed_content)
  return stemmed_content

# %%
twitter_data['stemmed_content']=twitter_data['text'].apply(stemming)

# %%
twitter_data.head()
# Out:
#                                                                   target  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                      "NO_QUERY"
# "0"       "1998864136"                    "Mon Jun 01 19:15:00 PDT 2009"
#           "1998864367"                    "Mon Jun 01 19:15:01 PDT 2009"
#           "1998864497"                    "Mon Jun 01 19:15:02 PDT 2009"
#           "1998864564"                    "Mon Jun 01 19:15:02 PDT 2009"
#
#                                                      id  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "ana_cassini"
# "0"       "1998864136"                       "NO_QUERY"
#           "1998864367"                       "NO_QUERY"
#           "1998864497"                       "NO_QUERY"
#           "1998864564"                       "NO_QUERY"
#
#                                                                                        date  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  "Unf...Mel didn't twit today!  Watchin' some T...
# "0"       "1998864136"                                                          "stratagee"
#           "1998864367"                                                         "hbturner75"
#           "1998864497"                                                          "sher_in_a"
#           "1998864564"                                                         "move_a1ong"
#
#                                                                                        flag  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"                         taking a look at the forum
# "0"       "1998864136"                    "Vanished one day and I really hope he is oook...
#           "1998864367"                               "Wanting to be with my man but can't "
#           "1998864497"                                        "missing my sweet lily Ava! "
#           "1998864564"                                   "still sick  school tomorroww UGH"
#
#                                                                    user  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  listening to some music! Yeay
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN
#
#                                                                    text  \
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  I'm a multiple tasks person!"
# "0"       "1998864136"                                              NaN
#           "1998864367"                                              NaN
#           "1998864497"                                              NaN
#           "1998864564"                                              NaN
#
#                                               stemmed_content
# 98863667" "Mon Jun 01 19:14:57 PDT 2009"  multipl task person
# "0"       "1998864136"
#           "1998864367"
#           "1998864497"
#           "1998864564"

# %%
print(twitter_data['stemmed_content'])
# Out:
# 98863667"  "Mon Jun 01 19:14:57 PDT 2009"    multipl task person
# "0"        "1998864136"
#            "1998864367"
#            "1998864497"
#            "1998864564"
#                                                     ...
#            "2053735206"
#            "2053735385"
#            "2053735809"
#            "2053736059"
#            "2053736204"
# Name: stemmed_content, Length: 83067, dtype: object

# %%
print(twitter_data['target'])
# Out:
# 98863667"  "Mon Jun 01 19:14:57 PDT 2009"                        "NO_QUERY"
# "0"        "1998864136"                      "Mon Jun 01 19:15:00 PDT 2009"
#            "1998864367"                      "Mon Jun 01 19:15:01 PDT 2009"
#            "1998864497"                      "Mon Jun 01 19:15:02 PDT 2009"
#            "1998864564"                      "Mon Jun 01 19:15:02 PDT 2009"
#                                                           ...
#            "2053735206"                      "Sat Jun 06 05:32:26 PDT 2009"
#            "2053735385"                      "Sat Jun 06 05:32:28 PDT 2009"
#            "2053735809"                      "Sat Jun 06 05:32:33 PDT 2009"
#            "2053736059"                      "Sat Jun 06 05:32:36 PDT 2009"
#            "2053736204"                      "Sat Jun 06 05:32:38 PDT 2009"
# Name: target, Length: 83067, dtype: object

# %%
# Seprating the data and label
X=twitter_data['stemmed_content'].values
Y=twitter_data['target'].values

# %%
print(X)
# Out:
# ['multipl task person' '' '' ... '' '' '']

# %%
print(Y)
# Out:
# ['"NO_QUERY"' '"Mon Jun 01 19:15:00 PDT 2009"'
#  '"Mon Jun 01 19:15:01 PDT 2009"' ... '"Sat Jun 06 05:32:33 PDT 2009"'
#  '"Sat Jun 06 05:32:36 PDT 2009"' '"Sat Jun 06 05:32:38 PDT 2009"']

# %% [markdown]
# Splitting the data into training data and test Data

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=2)

# %%
print(X.shape,X_train.shape,X_test.shape)
# Out:
# (83067,) (66453,) (16614,)

# %%
print(X_train)
# Out:
# ['' '' '' ... '' '' '']

# %%
print(X_test)
# Out:
# ['' '' '' ... '' '' '']

# %%
#converting the textual data to numerical data
vectorizer=TfidfVectorizer()
vectorizer.fit(X_train)
X_train=vectorizer.transform(X_train)
X_test=vectorizer.transform(X_test)

# %%
print(X_train)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 9746 stored elements and shape (66453, 3096)>
#   Coords	Values
#   (8, 1100)	0.602210460240932
#   (8, 1476)	0.7983373732804976
#   (75, 1106)	0.7197788986814574
#   (75, 1120)	0.6942033830318808
#   (117, 2489)	1.0
#   (139, 1172)	0.4014346706650956
#   (139, 1183)	0.38065584813904957
#   (139, 1484)	0.3763669708897371
#   (139, 1681)	0.4794987781387945
#   (139, 2663)	0.43163398978555495
#   (139, 2953)	0.36887972879251224
#   (152, 28)	0.42048458179297415
#   (152, 520)	0.40554372978723735
#   (152, 606)	0.34385991617431994
#   (152, 1091)	0.3082979638558369
#   (152, 2643)	0.42048458179297415
#   (152, 3016)	0.39494302658675606
#   (152, 3067)	0.3356373719663217
#   (159, 510)	0.33858899674923243
#   (159, 883)	0.4631006657301058
#   (159, 1464)	0.3425514866603174
#   (159, 1499)	0.43497047563051844
#   (159, 1605)	0.43497047563051844
#   (159, 1999)	0.4185153692841023
#   (183, 536)	0.5594812529629691
#   :	:
#   (66211, 2736)	0.3598138234215687
#   (66211, 3047)	0.3598138234215687
#   (66252, 86)	0.36995728834488834
#   (66252, 962)	0.49492383696470865
#   (66252, 1817)	0.5559595310832559
#   (66252, 2477)	0.5559595310832559
#   (66287, 605)	0.5469504437701761
#   (66287, 739)	0.5469504437701761
#   (66287, 753)	0.5030313800095974
#   (66287, 2926)	0.3855513647295969
#   (66289, 1650)	1.0
#   (66312, 2307)	0.7197788986814574
#   (66312, 2875)	0.6942033830318808
#   (66336, 68)	0.4154144741907
#   (66336, 1485)	0.3728337048800817
#   (66336, 1818)	0.4154144741907
#   (66336, 2236)	0.4422799484787315
#   (66336, 2288)	0.4422799484787315
#   (66336, 3067)	0.3530347746588457
#   (66417, 328)	0.6153292080703697
#   (66417, 1361)	0.5992448210456625
#   (66417, 2606)	0.5121285094050549
#   (66428, 1075)	0.6087113377753643
#   (66428, 1658)	0.6087113377753643
#   (66428, 1728)	0.5088624711328718

# %% [markdown]
# Traning the ML MODEL

# %%
model=LogisticRegression(max_iter=1000)

# %%
model.fit(X_train,y_train)
